# %% [markdown]
# # Session 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# Import data to notebook as "data":
data = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
print(data.head())
print(data.tail())
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
# Max Price:
print('Brand with Max Price:')
data[data['Price'] == data['Price'].max()]
# Out:
# Brand with Max Price:
#      Manufacturer Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 58  Mercedes-Benz  300E  Midsize       43.8   61.9       80.0      19.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 58         25.0  Driver & Passenger       Rear  ...        5.0     NaN
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# 58      110.0   69.0         37.0            NaN          15.0  3525.0
#
#      Origin                Make
# 58  non-USA  Mercedes-Benz 300E
#
# [1 rows x 27 columns]

# %%
# Missing Values:
# pd.isnull(data)
pd.isnull(data).sum()
# Out:
# Manufacturer           4
# Model                  1
# Type                   3
# Min.Price              7
# Price                  2
# Max.Price              5
# MPG.city               9
# MPG.highway            2
# AirBags                6
# DriveTrain             7
# Cylinders              5
# EngineSize             2
# Horsepower             7
# RPM                    3
# Rev.per.mile           6
# Man.trans.avail        5
# Fuel.tank.capacity     8
# Passengers             2
# Length                 4
# Wheelbase              1
# Width                  6
# Turn.circle            5
# Rear.seat.room         4
# Luggage.room          19
# Weight                 7
# Origin                 5
# Make                   3
# dtype: int64

# %%
# Replacing missing values:
min_mean = data['Min.Price'].mean()
max_mean = data['Max.Price'].mean()
values = {'Min.Price': min_mean, 'Max.Price': max_mean}
data.fillna(values, inplace = True)
data
# Out:
#    Manufacturer          Model     Type  Min.Price  Price  Max.Price  \
# 0         Acura        Integra    Small  12.900000   15.9  18.800000
# 1           NaN         Legend  Midsize  29.200000   33.9  38.700000
# 2          Audi             90  Compact  25.900000   29.1  32.300000
# 3          Audi            100  Midsize  17.118605   37.7  44.600000
# 4           BMW           535i  Midsize  17.118605   30.0  21.459091
# 5         Buick        Century  Midsize  14.200000   15.7  17.300000
# 6         Buick        LeSabre    Large  19.900000   20.8  21.459091
# 7         Buick     Roadmaster    Large  22.600000   23.7  24.900000
# 8         Buick        Riviera  Midsize  26.300000   26.3  26.300000
# 9      Cadillac        DeVille    Large  33.000000   34.7  36.300000
# 10     Cadillac        Seville  Midsize  37.500000   40.1  42.700000
# 11    Chevrolet       Cavalier  Compact   8.500000   13.4  18.300000
# 12    Chevrolet        Corsica  Compact  11.400000   11.4  11.400000
# ...

# %%
# Sorting cars based on 'Price':
data.sort_values(by = 'Price', inplace = True, ascending = True)
data.reset_index(drop = True, inplace = True)     # Reindexing
data
# Out:
#      Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 0            Ford         Festiva    Small   6.900000    7.4   7.900000
# 1         Hyundai           Excel    Small   6.800000    8.0   9.200000
# 2           Mazda             323    Small   7.400000    8.3   9.100000
# 3             Geo           Metro    Small   6.700000    8.4  10.000000
# 4          Subaru           Justy    Small   7.300000    8.4   9.500000
# 5          Suzuki           Swift      NaN   7.300000    8.6  21.459091
# 6         Pontiac          LeMans    Small  17.118605    9.0   9.900000
# 7      Volkswagen             Fox    Small   8.700000    9.1   9.500000
# 8           Dodge            Colt    Small   7.900000    9.2  10.600000
# 9          Toyota          Tercel    Small  17.118605    9.8  11.800000
# 10        Hyundai         Elantra    Small   9.000000   10.0  11.000000
# 11        Hyundai          Scoupe      NaN   9.100000   10.0  11.000000
# ...
